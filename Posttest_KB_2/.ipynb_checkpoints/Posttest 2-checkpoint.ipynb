# %% [markdown]
# # POSTTEST 2

# %% [markdown]
# Membaca dataset netflix sehingga didapatkan jumlah baris dan kolom dalam dataset

# %%
import pandas as pd

dataNetflix = pd.read_csv("netflix.csv")
print(dataNetflix)
# Out:
#                             Name    Year Age Rating Duration  \
# 0                  The Sea Beast  2022.0         7+   1h 59m
# 1             Sonic the Hedgehog  2020.0         7+   1h 41m
# 2                  Tom and Jerry  2021.0         7+   1h 41m
# 3               We Can Be Heroes  2020.0         7+   1h 40m
# 4         STAND BY ME Doraemon 2  2020.0         7+   1h 37m
# ...                          ...     ...        ...      ...
# 2724                         Mom  2017.0        16+   2h 18m
# 2725  The Legend of Bhagat Singh  2002.0        16+   2h 35m
# 2726                  Article 15  2019.0        16+    2h 5m
# 2727               We Are Family  2010.0        13+   1h 58m
# 2728             Ajeeb Daastaans  2021.0        18+   2h 22m
#
#                        Category      Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0          Kids & Family Movies NaN         NaN         NaN        NaN
# 1          Kids & Family Movies NaN         NaN         NaN   Duration
# ...

# %% [markdown]
# perintah berikut digunakan untuk melihat jumlah baris dalam dataset, nama-nama kolom, jumlah data, dan tipe data di dalam dataset

# %%
dataNetflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2729 entries, 0 to 2728
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2728 non-null   object
#  1   Year          2704 non-null   float64
#  2   Age Rating    2704 non-null   object
#  3   Duration      2728 non-null   object
#  4   Category      2727 non-null   object
#  5                 0 non-null      float64
#  6   Unnamed: 6    0 non-null      float64
#  7   Unnamed: 7    0 non-null      float64
#  8   Unnamed: 8    144 non-null    object
#  9   Age Rating.1  66 non-null     object
#  10  Values        65 non-null     object
#  11  Unnamed: 11   76 non-null     object
#  12  Unnamed: 12   75 non-null     object
#  13  Unnamed: 13   50 non-null     object
#  14  Unnamed: 14   49 non-null     object
#  15  Unnamed: 15   47 non-null     object
#  16  Unnamed: 16   46 non-null     object
#  17  Unnamed: 17   33 non-null     object
# ...

# %% [markdown]
# perintah berikut digunakan untuk menampilkan deskriptif statistik data didalam dataset. Biasanya yang akan ditampilkan hanya kolom bertipe numerik. Namun untuk describe all maka semua data akan ditampilkan.

# %% [markdown]
# Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
dataNetflix.describe()
# Out:
#               Year       Unnamed: 6  Unnamed: 7
# count  2704.000000  0.0         0.0         0.0
# mean   2014.891642  NaN         NaN         NaN
# std       8.332022  NaN         NaN         NaN
# min    1954.000000  NaN         NaN         NaN
# 25%    2012.000000  NaN         NaN         NaN
# 50%    2018.000000  NaN         NaN         NaN
# 75%    2020.000000  NaN         NaN         NaN
# max    2022.000000  NaN         NaN         NaN

# %%
dataNetflix.describe(include="all")
# Out:
#                 Name         Year Age Rating Duration  Category       \
# count           2728  2704.000000       2704     2728      2727  0.0
# unique          1812          NaN          9      174        69  NaN
# top     Little Women          NaN        13+   1h 30m  Comedies  NaN
# freq               5          NaN        737       67       457  NaN
# mean             NaN  2014.891642        NaN      NaN       NaN  NaN
# std              NaN     8.332022        NaN      NaN       NaN  NaN
# min              NaN  1954.000000        NaN      NaN       NaN  NaN
# 25%              NaN  2012.000000        NaN      NaN       NaN  NaN
# 50%              NaN  2018.000000        NaN      NaN       NaN  NaN
# 75%              NaN  2020.000000        NaN      NaN       NaN  NaN
# max              NaN  2022.000000        NaN      NaN       NaN  NaN
#
#         Unnamed: 6  Unnamed: 7 Unnamed: 8 Age Rating.1  ... Unnamed: 11  \
# ...

# %% [markdown]
# perintah berikut digunakan untuk menghitung jumlah baris data yang tidak bernilai NaN didalam dataset

# %%
dataNetflix.count()
# Out:
# Name            2728
# Year            2704
# Age Rating      2704
# Duration        2728
# Category        2727
#                    0
# Unnamed: 6         0
# Unnamed: 7         0
# Unnamed: 8       144
# Age Rating.1      66
# Values            65
# Unnamed: 11       76
# Unnamed: 12       75
# Unnamed: 13       50
# Unnamed: 14       49
# Unnamed: 15       47
# Unnamed: 16       46
# Unnamed: 17       33
# Unnamed: 18       32
# Unnamed: 19      144
# Unnamed: 20      144
# dtype: int64

# %% [markdown]
# perintah ini digunakan untuk mengambil 10 data pertama dari dataset

# %%
dataNetflix.head(10)
# Out:
#                       Name    Year Age Rating Duration              Category  \
# 0            The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies
# 1       Sonic the Hedgehog  2020.0         7+   1h 41m  Kids & Family Movies
# 2            Tom and Jerry  2021.0         7+   1h 41m  Kids & Family Movies
# 3         We Can Be Heroes  2020.0         7+   1h 40m  Kids & Family Movies
# 4   STAND BY ME Doraemon 2  2020.0         7+   1h 37m  Kids & Family Movies
# 5  The Angry Birds Movie 2  2019.0         7+   1h 36m  Kids & Family Movies
# 6  The Secret Life of Pets  2016.0        All   1h 26m  Kids & Family Movies
# 7      Back to the Outback  2021.0         7+   1h 35m  Kids & Family Movies
# 8          Kung Fu Panda 3  2016.0         7+   1h 34m  Kids & Family Movies
# 9           The Karate Kid  2010.0         7+   2h 20m  Kids & Family Movies
#
#        Unnamed: 6  Unnamed: 7 Unnamed: 8       Age Rating.1  ...  \
# ...

# %% [markdown]
# perintah di bawah digunakan untuk mengecek tipe data tiap kolom di dalam dataset. namun bisa juga digunakan untuk mengecek tipe data salah satu kolom saja seperti berikut.

# %%
dataNetflix.dtypes
# Out:
# Name             object
# Year            float64
# Age Rating       object
# Duration         object
# Category         object
#                 float64
# Unnamed: 6      float64
# Unnamed: 7      float64
# Unnamed: 8       object
# Age Rating.1     object
# Values           object
# Unnamed: 11      object
# Unnamed: 12      object
# Unnamed: 13      object
# Unnamed: 14      object
# Unnamed: 15      object
# Unnamed: 16      object
# Unnamed: 17      object
# Unnamed: 18      object
# Unnamed: 19      object
# Unnamed: 20      object
# dtype: object

# %%
dataNetflix['Duration'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# perintah dibawah ini digunakan untuk menjumlahkan bilangan numerik yang tidak null pada dataset berdasarkan kolom yang terdapat di dataset yang digunakan.

# %%
dataNetflix.isnull().sum()
# Out:
# Name               1
# Year              25
# Age Rating        25
# Duration           1
# Category           2
#                 2729
# Unnamed: 6      2729
# Unnamed: 7      2729
# Unnamed: 8      2585
# Age Rating.1    2663
# Values          2664
# Unnamed: 11     2653
# Unnamed: 12     2654
# Unnamed: 13     2679
# Unnamed: 14     2680
# Unnamed: 15     2682
# Unnamed: 16     2683
# Unnamed: 17     2696
# Unnamed: 18     2697
# Unnamed: 19     2585
# Unnamed: 20     2585
# dtype: int64

# %% [markdown]
# menghitung nilai rata-rata dari salah satu kolom bertipe numerik didalam dataset, melihat size dataset, melihat ukuran dataset (baris,kolom), dan melihat ada kolom apa saja yang terdapat didalam dataset.

# %%
dataNetflix['Year'].mean()
# Out:
# 2014.8916420118344

# %%
dataNetflix.size
# Out:
# 57309

# %%
dataNetflix.shape
# Out:
# (2729, 21)

# %%
dataNetflix.columns
# Out:
# Index(['Name', 'Year', 'Age Rating', 'Duration', 'Category', ' ', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Age Rating.1', 'Values', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %% [markdown]
# perintah berikut digunakan untuk menampilkan nilai korelasi di dialam dataset

# %%
dataNetflix.corr()
# Out:
#             Year      Unnamed: 6  Unnamed: 7
# Year         1.0 NaN         NaN         NaN
#              NaN NaN         NaN         NaN
# Unnamed: 6   NaN NaN         NaN         NaN
# Unnamed: 7   NaN NaN         NaN         NaN

# %% [markdown]
# Merubah nilai attribute bertipe angka menjadi desimal 3 angka dibelakang koma jika tidak ada, lakukan sebaliknya (dari desimal menjadi bilangan bulat).

# %%
dn = dataNetflix['Year']*0.001
print(dn)
# Out:
# 0       2.022
# 1       2.020
# 2       2.021
# 3       2.020
# 4       2.020
#         ...
# 2724    2.017
# 2725    2.002
# 2726    2.019
# 2727    2.010
# 2728    2.021
# Name: Year, Length: 2729, dtype: float64

# %% [markdown]
# Menampilkan 10 record pertama dari attribute bertipe angka.

# %%
dataNetflix[['Year', 'Unnamed: 6', 'Unnamed: 12', 'Unnamed: 20']].head(10)
# Out:
#      Year  Unnamed: 6  Unnamed: 12        Unnamed: 20
# 0  2022.0         NaN          NaN  Total Sum of Year
# 1  2020.0         NaN  Sum of Year                NaN
# 2  2021.0         NaN         8076              26211
# 3  2020.0         NaN         4043              24236
# 4  2020.0         NaN        10092              24177
# 5  2019.0         NaN         2018              24175
# 6  2016.0         NaN         2017              22168
# 7  2021.0         NaN         2005              22157
# 8  2016.0         NaN         8069              22178
# 9  2010.0         NaN        10076              22179

# %% [markdown]
# Simpan dataset dengan attribute bertipe angka ke dalam file CSV.

# %%
dn = dataNetflix[['Year', 'Unnamed: 6', 'Unnamed: 12', 'Unnamed: 20']].copy()
dn.to_csv("netflix_numberType.csv")
